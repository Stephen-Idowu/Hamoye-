# %%
# Data Visualization and Representation in Python

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (7,4))
plt.xticks(rotation = 90)

fuel_unit = pd.DataFrame({'unit':['BBL','GAL', 'GRAM','KGU','MCF',
                          'MMBTU','MWDTH', 'MWHTH', 'TON'],
                          'count':[7998, 84, 464, 110, 11354, 180, 90, 100, 8958]})

sns.barplot(data = fuel_unit, x = 'unit', y = 'count')
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %%
g = sns.barplot(data = fuel_unit, x = 'unit', y = 'count')
g.set_yscale("log")
g.set_ylim(1, 12000)
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %%
import seaborn as sns

url='https://github.com/WalePhenomenon/climate_change/blob/master/fuel_ferc1.csv?raw=true'

fuel_data = pd.read_csv(url, error_bad_lines = False)

sample_df = fuel_data.sample(n = 50, random_state = 4)
sns.regplot(x=sample_df["fuel_qty_burned"], y = sample_df["fuel_cost_per_mmbtu"])
# Out:
# <AxesSubplot:xlabel='fuel_qty_burned', ylabel='fuel_cost_per_mmbtu'>

# %%
sample_df = fuel_data.sample(n = 50, random_state = 4)
sns.regplot(x=sample_df["fuel_cost_per_unit_delivered"], y = sample_df["fuel_cost_per_mmbtu"])
# Out:
# <AxesSubplot:xlabel='fuel_cost_per_unit_delivered', ylabel='fuel_cost_per_mmbtu'>

# %%
import seaborn as sns
sns.boxplot(x="fuel_type_code_pudl", y="utility_id_ferc1",
palette=["m", "g"], data=fuel_data)
# Out:
# <AxesSubplot:xlabel='fuel_type_code_pudl', ylabel='utility_id_ferc1'>
